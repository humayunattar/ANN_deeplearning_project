# %%
import pandas as pd
import numpy as np

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import load_model
import pickle

# %%
models=load_model('models.h5')
with open('scaler.pkl', 'rb') as file:
    scaler = pickle.load(file)
with open('label_encoder_gender.pkl', 'rb') as file:
    label_encoder_gender=pickle.load(file)
with open('one_hot_encoder_geography.pkl', 'rb') as file:
    one_hot_encoder_geography=pickle.load(file)
# Out:
# WARNING:tensorflow:From c:\Users\Asus\Desktop\dl_project\venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
os.getcwd()
print(os.listdir())
# Out:
# ['.git', 'Churn_Modelling.csv', 'experiment.ipynb', 'label_encoder_gender.pkl', 'logs', 'models.h5', 'one_hot_encoder_geography.pkl', 'prediction.ipynb', 'README.md', 'requirements.txt', 'scaler.pkl', 'venv']

# %%
input_data={
    'CreditScore': 600,
    'Geography': 'France',
    'Gender': 'Male',
    'Age': 40,
    'Tenure': 2,
    'Balance': 0.0,
    'NumOfProducts': 1,
    'HasCrCard': 1,
    'IsActiveMember': 1,
    'EstimatedSalary': 50000
}

# %%
geography_encoded=one_hot_encoder_geography.transform([[input_data['Geography']]]).toarray()
geography_encoded_df=pd.DataFrame(geography_encoded, columns=one_hot_encoder_geography.get_feature_names_out(['Geography']))
# Out:
# c:\Users\Asus\Desktop\dl_project\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
geography_encoded_df
# Out:
#    Geography_France  Geography_Germany  Geography_Spain
# 0               1.0                0.0              0.0

# %%
input_df=pd.DataFrame([input_data])

# %%
input_df['Gender']=label_encoder_gender.transform(input_df['Gender'])

# %%
input_df
# Out:
#    CreditScore Geography  Gender  Age  Tenure  Balance  NumOfProducts  \
# 0          600    France       1   40       2      0.0              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1            50000

# %%
input_df=pd.concat([input_df.drop(['Geography'], axis=1), geography_encoded_df], axis=1)

# %%
input_df
# Out:
#    CreditScore  Gender  Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# 0          600       1   40       2      0.0              1          1
#
#    IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0               1            50000               1.0                0.0
#
#    Geography_Spain
# 0              0.0

# %%
input_scaled=scaler.transform(input_df)

# %%
prediction=models.predict(input_scaled)
print("Predicted probability of churn:", prediction[0][0])
# Out:
# 1/1 [==============================] - 0s 180ms/step
# Predicted probability of churn: 0.055742554

# %%
prediction_probability=prediction[0][0]
print(prediction_probability)
# Out:
# 0.055742554

# %%
if prediction_probability >0.5:
    print("The customer is likely to churn.")
else:
    print("The customer is unlikely to churn.")
# Out:
# The customer is unlikely to churn.
